# %% [markdown]
# # for-loop version

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import re

# %%
my_url = "http://www.lunduniversity.lu.se/lubas/programs"


# open connection and downloading the web page
download = urlopen(my_url)
page_html = download.read() # dumping everything as HTML
download.close() # close the internet connection

# parse
page_soup = soup(page_html, "html.parser")

# %%
# university programs were grouped by letter so make containers based on 
# the program grouping
containers = page_soup.find_all("div", class_="program-group")


# make filename for csv file and open the file to start writing into
filename = "lund_university_programs.csv"
f = open(filename, "w")

headers = "international_degree_program" + "," + "education_level\n" # make headers and add new line because its a csv

f.write(headers) # writes the headers in your file. Start adding loop result

# loop through containers to extract
for container in containers:
    container_span = container.find_all('span') # degree programs can be found in span tag
    for program in container_span:
        program = program.string
        program_split = re.split(' - Ma| - B', program) # "|" mean OR. re.split splits on multiple patters. Can't use ' - M'... 
                                                        # because there is several in some programs

        program_name = program_split[0]  # program name is first element in the split... 
                                         #second element is education level, or there was no split at all


        # most programs have now been split into several elements so we loop through to clean the education levels
        for data in program_split:  
            category = None
            if 'ster' in data:
                category = "Master"
            elif 'achelor' in data:
                category = 'Bachelor'
            else:
                category = 'N/A'
        print("program: {} education, level: {}".format(program_name.replace(",", "|"), category))

        ##### write loop results into csv. "," makes new columns so change these. Must add new line at the end to deliminate
        f.write(program_name.replace(",", "|") + "," + category + "\n")

# close file
f.close()
# Out:
# program: Accounting and Finance education, level: Master
# program: Applied Cultural Analysis education, level: Master
# program: Archaeology - theory and practice education, level: Master
# program: Architecture education, level: Master
# program: Asian Studies education, level: Master
# program: Astrophysics education, level: Master
# program: Atmospheric Sciences and Biogeochemical Cycles education, level: Master
# program: Bioinformatics education, level: Master
# program: Biology| Animal Ecology education, level: Master
# program: Biology| Aquatic Ecology education, level: Master
# program: Biology| Conservation Biology education, level: Master
# program: Biology| General education, level: Master
# program: Biology| Plant Science education, level: Master
# program: Biomedicine education, level: Master
# program: Biotechnology education, level: Master
# program: Chemistry education, level: Master
# program: Church Music| Arrangement and Composition education, level: Master
# program: Church Music| Organ and Keyboard education, level: Master
# program: Church Music| Vocal Music and Choir education, level: Master
# program: Development Studies education, level: Bachelor
# program: Development Studies education, level: Master
# program: Disaster Risk Management and Climate Change Adaptation education, level: Master
# program: Economic Growth| Population and Development education, level: Master
# program: Economics education, level: Master
# program: Embedded Electronics Engineering education, level: Master
# program: Energy-efficient and Environmental Building Design education, level: Master
# program: Entrepreneurship and Innovation education, level: Master
# program: Environmental Management and Policy education, level: Master
# program: Environmental Studies and Sustainability Science education, level: N/A
# program: European Affairs education, level: Master
# program: European Business Law education, level: Master
# program: European Studies education, level: Master
# program: European and International Tax Law education, level: Master
# program: Finance education, level: Master
# program: Fine Arts education, level: Bachelor
# program: Fine Arts education, level: Master
# program: Food Technology and Nutrition education, level: Master
# program: Geographical Information Systems education, level: Master
# program: Geology| Bedrock Geology education, level: Master
# program: Geology| Quaternary Geology education, level: Master
# program: Geomatics education, level: Master
# program: Global Studies education, level: Master
# program: Human Ecology - Culture| Power and Sustainability education, level: Master
# program: Human Geography education, level: Master
# program: Industrial Design education, level: Master
# program: Information Systems education, level: Master
# program: Innovation and Global Sustainable Development education, level: Master
# program: International Business education, level: Bachelor
# program: International Development and Management education, level: Master
# program: International Economics with a focus on China education, level: Master
# program: International Human Rights Law education, level: Master
# program: International Marketing & Brand Management education, level: Master
# program: International Strategic Management education, level: Master
# program: Language and Linguistics| Arabic/Semitic Languages education, level: Master
# program: Language and Linguistics| Chinese education, level: Master
# program: Language and Linguistics| Cognitive semiotics education, level: Master
# program: Language and Linguistics| English education, level: Master
# program: Language and Linguistics| French education, level: Master
# program: Language and Linguistics| General Linguistics education, level: Master
# program: Language and Linguistics| Greek education, level: Master
# program: Language and Linguistics| Italian education, level: Master
# program: Language and Linguistics| Japanese education, level: Master
# program: Language and Linguistics| Latin education, level: Master
# program: Language and Linguistics| Modern Greek education, level: Master
# program: Language and Linguistics| Phonetics education, level: Master
# program: Language and Linguistics| Rhetoric education, level: Master
# program: Language and Linguistics| Spanish education, level: Master
# program: Language and Linguistics| Swedish/Scandinavian Languages education, level: Master
# program: Literature - Culture - Media| English Literature education, level: Master
# program: Literature - Culture - Media| French Literature education, level: Master
# program: Literature - Culture - Media| General Literature education, level: Master
# program: Literature - Culture - Media| German Literature education, level: Master
# program: Literature - Culture - Media| Russian Literature education, level: Master
# program: Literature - Culture - Media| Scandinavian Studies education, level: Master
# program: Literature - Culture - Media| Spanish Literature education, level: Master
# program: Literature - Culture - Media| Yiddish Literature education, level: Master
# program: Logistics and Supply Chain Management education, level: Master
# program: Management education, level: Master
# program: Managing People| Knowledge & Change education, level: Master
# program: Mathematical Statistics education, level: Master
# program: Mathematics education, level: Master
# program: Media and Communication Studies education, level: Master
# program: Medical Science| Ageing and Health education, level: Master
# program: Medical Science| Audiology education, level: Master
# program: Medical Science| Nursing education, level: Master
# program: Medical Science| Occupational Therapy education, level: Master
# program: Medical Science| Physiotherapy education, level: Master
# program: Medical Science| Reproductive| Perinatal and Sexual Health education, level: Master
# program: Medical Science| Speech and Language Pathology education, level: Master
# program: Middle Eastern Studies education, level: Master
# program: Molecular Biology| General education, level: Master
# program: Molecular Biology| Medical Biology education, level: Master
# program: Molecular Biology| Microbiology education, level: Master
# program: Molecular Biology| Molecular Genetics and Biotechnology education, level: Master
# program: Music| Composition education, level: Master
# program: Music| Composition Diploma education, level: Master
# program: Music| Guitar education, level: Master
# program: Music| Harpsichord education, level: Master
# program: Music| Interpretation Diploma education, level: Master
# program: Music| Jazz Improvisation education, level: Master
# program: Music| Piano education, level: Master
# program: Music| Recorder education, level: Master
# program: Music| Symphony Orchestra Instrument education, level: Bachelor
# program: Music| Symphony Orchestra Instrument education, level: Master
# program: Music| Vocal and Drama Studies education, level: Master
# program: Organizing Molecular Matter education, level: Master
# program: Physical Geography and Ecosystem Science education, level: Master
# program: Physics| Biological Physics and Computational Biology education, level: Master
# program: Physics| General education, level: Master
# program: Physics| Materials science education, level: Master
# program: Physics| Nanoscience education, level: Master
# program: Physics| Particle Physics education, level: Master
# program: Physics| Photonics education, level: Master
# program: Physics| Theoretical Physics education, level: Master
# program: Protein Science education, level: Master
# program: Psychology education, level: Master
# program: Public Health education, level: Master
# program: Religious Roots of Europe education, level: Master
# program: Sciences| Mathematics education, level: N/A
# program: Sciences| Physical Geography and Ecosystem Science education, level: N/A
# program: Sciences| Physics education, level: N/A
# program: Service Management| Retail education, level: Master
# program: Service Management| Supply Chain Management education, level: Master
# program: Service Management| Tourism education, level: Master
# program: Social Anthropology education, level: Master
# program: Social Studies of Gender education, level: Master
# program: Sociology education, level: Master
# program: Sociology of Law education, level: Master
# program: Strategic Communication education, level: Master
# program: Sustainable Urban Design education, level: Master
# program: Synchrotron Radiation Based Science education, level: Master
# program: Visual Culture education, level: Master
# program: Water Resources Engineering education, level: Master
# program: Welfare Policies and Management education, level: Master
# program: Wireless Communications education, level: Master
